# %% [markdown]
# # Guided Capstone Step 6. Documentation

# %% [markdown]
# **The Data Science Method**
#
#
# 1.   Problem Identification
#
# 2.   Data Wrangling
#
# 3.   Exploratory Data Analysis
#
# 4.   Pre-processing and Training Data Development
#
# 5.  Modeling
#
# 6.   **Documentation**
#   * Review the Results
#   * Finalize Code
#   * Finalize Documentation
#   * Create a Project Report
#   * Create a Slide Deck for the Executive Audience

# %% [markdown]
# In this guided capstone we are going to revisit many of the actions we took in the previous guided capstone steps. This gives you the opportunity to practice the code you wrote to solve the questions in step 4 and 5.

# %% [markdown]
# **<font color='teal'> Start by loading the necessary packages and printing out our current working directory just to confirm we are in the correct project directory. </font>**

# %%
#load python packages
import os
import pandas as pd
import datetime
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Pranay\\Projects\\GitHub\\Guided-Capstone'

# %% [markdown]
# ## Fit Models with Training Dataset

# %% [markdown]
# **<font color='teal'> Using sklearn fit the model you chose in Guided Capstone 5 on your training dataset. This includes: creating dummy features for states if you need them, scaling the data,and creating train and test splits before fitting the chosen model.Also, remember to generate a model performance score(MAE, or explained variance) based on the testing hold-out data set.</font>**

# %% [markdown]
# #### Best Model

# %%
df=pd.read_csv('data/step3_output.csv')
#df.head()

# %%
# first we import the preprocessing package from the sklearn library
from sklearn import preprocessing

# Declare an explanatory variable, called X,and assign it the result of dropping 'Name' and 'AdultWeekend' from the df
X = df.drop(['Name','AdultWeekend','state','summit_elev'], axis=1)

# Declare a response variable, called y, and assign it the AdultWeekend column of the df 
Y= df.AdultWeekend

# Here we use the StandardScaler() method of the preprocessing package, and then call the fit() method with parameter X 
scaler = preprocessing.StandardScaler().fit(X)

# Declare a variable called X_scaled, and assign it the result of calling the transform() method with parameter X 
X_scaled=scaler.transform(X)

# %%
# Import the train_test_split function from the sklearn.model_selection utility.  
from sklearn.model_selection import train_test_split

# Get the 1-dimensional flattened array of our response variable y by calling the ravel() function on y
Y = Y.ravel()

# Call the train_test_split() function with the first two parameters set to X_scaled and y 
# Declare four variables, X_train, X_test, y_train and y_test separated by commas 
X_train, X_test, Y_train, Y_test = train_test_split(X_scaled, Y, test_size=0.25, random_state=1)

# %%
#all first model set
from sklearn import linear_model
from sklearn.metrics import explained_variance_score,mean_absolute_error
lm = linear_model.LinearRegression()
model = lm.fit(X_train,Y_train)

# %%
# Make a variable called y_pred and assign it the result of calling predict() on our model variable with parameter X_test
y_pred = model.predict(X_test)
#y_pred

# %%
from sklearn.metrics import explained_variance_score
evs=explained_variance_score(Y_test, y_pred)
evs
# Out:
# 0.8124586881811285

# %%
mbe=mean_absolute_error(Y_test, y_pred)
mbe
# Out:
# 5.941492328505132

# %%
lm.intercept_
# Out:
# 56.888279389968645

# %%
# You might want to make a pandas DataFrame displaying the coefficients for each state like so: 
pd.DataFrame(abs(lm.coef_), X.columns, columns=['Coefficient'])
# Out:
#                     Coefficient
# vertical_drop      3.440372e+00
# trams              8.881784e-16
# fastEight          1.776357e-15
# fastSixes          1.332268e-15
# fastQuads          6.670755e-01
# quad               6.789866e-01
# triple             1.140387e+00
# double             5.792964e-01
# surface            2.752390e-01
# total_chairs       7.066122e-01
# Runs               9.042044e-02
# TerrainParks       6.375782e-01
# LongestRun_mi      6.968007e-01
# SkiableTerrain_ac  2.249795e+00
# Snow Making_ac     2.068074e+00
# daysOpenLastYear   1.486910e+00
# yearsOpen          2.792123e-01
# averageSnowfall    3.443605e+00
# AdultWeekday       9.773515e+00
# projectedDaysOpen  2.117846e-01
# NightSkiing_ac     7.871717e-01
# clusters           2.382692e+00

# %% [markdown]
# ## Review the results

# %% [markdown]
# **<font color='teal'> Now, let's predict the Big Mountain Weekend price with our model in order to provide a recommendation to our managers on how to price the `AdultWeekend` lift ticket. First we need to find the row for Big Mountain resort in our data using string contains or string matching.</font>**

# %%
df[df['Name'].str.contains('Big Mountain')]
# Out:
#                     Name    state  summit_elev  vertical_drop  trams  \
# 173  Big Mountain Resort  Montana         6817           2353      0
#
#      fastEight  fastSixes  fastQuads  quad  triple  ...  SkiableTerrain_ac  \
# 173        0.0          0          3     2       6  ...             3000.0
#
#      Snow Making_ac  daysOpenLastYear  yearsOpen  averageSnowfall  \
# 173           600.0             123.0       72.0            333.0
#
#      AdultWeekday  AdultWeekend  projectedDaysOpen  NightSkiing_ac  clusters
# 173          81.0          81.0              123.0           600.0         1
#
# [1 rows x 26 columns]

# %% [markdown]
# **<font color='teal'> Prepare the Big Mountain resort data row as you did in the model fitting stage.</font>**

# %%
ac=df[df['Name'].str.contains('Big Mountain')]

# %%
X=ac.drop(['Name','AdultWeekend','state','summit_elev'], axis=1)

# %%
X_scaled=scaler.transform(X)

# %%
model.predict(X_scaled)
# Out:
# array([74.75062982])

# %%
model.predict(X)

# %% [markdown]
# **<font color='teal'> Predict the Big Mountain resort `Adult Weekend` price and print it out.</font>** This is our expected price to present to management. Based on our model given the characteristics of the resort in comparison to other ski resorts and their unique characteristics.

# %% [markdown]
# **<font color='teal'> Print the Big Mountain resort actual `Adult Weekend` price.</font>**

# %%
print(df[df['Name'].str.contains('Big Mountain')].AdultWeekend)
# Out:
# 173    81.0
# Name: AdultWeekend, dtype: float64

# %% [markdown]
# **<font color='teal'> As part of reviewing the results it is an important step to generate figures to visualize the data story. We can use the clusters we added to our data frame to create scatter plots for visualizing the Adult Weekend values compared to other characteristics. Run the example below to get you started and build two or three more figures to include in your data story telling.</font>**

# %%
plt.scatter(df['summit_elev'], df['vertical_drop'], c=df['clusters'], s=50, cmap='viridis', label ='clusters')
plt.scatter(ac['summit_elev'], ac['vertical_drop'], c='black', s=100)
plt.xlabel('summit_elev')
plt.ylabel('vertical_drop')
plt.title('summit_elev by vertical_drop by cluster')
plt.savefig('figures/fig1.png',bbox_inches='tight')

# %%
plt.scatter(df['AdultWeekend'], df['AdultWeekday'], c=df['clusters'], s=50, cmap='viridis', label ='clusters')
plt.scatter(ac['AdultWeekend'], ac['AdultWeekday'], c='black', s=100)
plt.xlabel('summit_elev')
plt.ylabel('vertical_drop')
plt.title('summit_elev by vertical_drop by cluster')
plt.savefig('figures/fig1.png',bbox_inches='tight')

# %%
plt.scatter(df['daysOpenLastYear'], df['projectedDaysOpen'], c=df['clusters'], s=50, cmap='viridis', label ='clusters')
plt.scatter(ac['daysOpenLastYear'], ac['projectedDaysOpen'], c='black', s=100)
plt.xlabel('summit_elev')
plt.ylabel('vertical_drop')
plt.title('summit_elev by vertical_drop by cluster')
plt.savefig('figures/fig1.png',bbox_inches='tight')

# %% [markdown]
# ## Finalize Code

# %% [markdown]
#  Making sure our code is well organized and easy to follow is an important step. This is the time where you need to review the notebooks and Python scripts you've created and clean them up so they are easy to follow and succinct in nature. Addtionally, we will also save our final model as a callable object using Pickle for future use in a data pipeline. Pickle is a module that serializes (and de-serializes) Python objects so that they can become executable objects like functions. It's used extensively in production environments where machine learning models are deployed on an industrial scale!**<font color='teal'> Run the example code below to save out your callable model. Notice that we save it in the models folder we created in our previous guided capstone step.</font>**

# %%
import pickle
s = pickle.dumps(model)
from joblib import dump, load
dump(model, 'models/regression_model_adultweekend.joblib')
# Out:
# ['models/regression_model_adultweekend.joblib']

# %% [markdown]
# ## Finalize Documentation

# %% [markdown]
# For model documentation, we want to save the model performance metrics as well as the features included in the final model. You could also save the model perfomance metrics and coefficients fo the other models you tried in case you want to refer to them later. **<font color='teal'> Create a dataframe containing the coefficients and the model performance metrics and save it out as a csv file, then upload it to your github repository.</font>**

# %%
from sklearn import metrics

# %%
df.corr().abs()
# Out:
#                    summit_elev  vertical_drop  trams  fastEight  fastSixes  \
# summit_elev           1.000000       0.608290    NaN        NaN        NaN
# vertical_drop         0.608290       1.000000    NaN        NaN        NaN
# trams                      NaN            NaN    NaN        NaN        NaN
# fastEight                  NaN            NaN    NaN        NaN        NaN
# fastSixes                  NaN            NaN    NaN        NaN        NaN
# fastQuads             0.156227       0.440420    NaN        NaN        NaN
# quad                  0.019733       0.003250    NaN        NaN        NaN
# triple                0.098661       0.149976    NaN        NaN        NaN
# double                0.064369       0.188041    NaN        NaN        NaN
# surface               0.368090       0.305934    NaN        NaN        NaN
# total_chairs          0.079106       0.107385    NaN        NaN        NaN
# Runs                  0.487057       0.759630    NaN        NaN        NaN
# TerrainParks          0.022849       0.119426    NaN        NaN        NaN
# LongestRun_mi         0.383749       0.664452    NaN        NaN        NaN
# SkiableTerrain_ac     0.564284       0.663569    NaN        NaN        NaN
# Snow Making_ac        0.016761       0.302954    NaN        NaN        NaN
# daysOpenLastYear      0.326688       0.304855    NaN        NaN        NaN
# yearsOpen             0.205113       0.241737    NaN        NaN        NaN
# averageSnowfall       0.693658       0.594301    NaN        NaN        NaN
# AdultWeekday          0.412575       0.642132    NaN        NaN        NaN
# AdultWeekend          0.245119       0.572197    NaN        NaN        NaN
# projectedDaysOpen     0.281628       0.290717    NaN        NaN        NaN
# NightSkiing_ac        0.129007       0.000763    NaN        NaN        NaN
# clusters              0.553617       0.577899    NaN        NaN        NaN
#
#                    fastQuads      quad    triple    double   surface  ...  \
# summit_elev         0.156227  0.019733  0.098661  0.064369  0.368090  ...
# vertical_drop       0.440420  0.003250  0.149976  0.188041  0.305934  ...
# trams                    NaN       NaN       NaN       NaN       NaN  ...
# fastEight                NaN       NaN       NaN       NaN       NaN  ...
# fastSixes                NaN       NaN       NaN       NaN       NaN  ...
# fastQuads           1.000000  0.183104  0.261190  0.116703  0.067022  ...
# quad                0.183104  1.000000  0.188100  0.173845  0.186237  ...
# triple              0.261190  0.188100  1.000000  0.126445  0.111511  ...
# double              0.116703  0.173845  0.126445  1.000000  0.004821  ...
# surface             0.067022  0.186237  0.111511  0.004821  1.000000  ...
# total_chairs        0.479908  0.380116  0.549704  0.447191  0.618126  ...
# Runs                0.466848  0.140430  0.248108  0.261642  0.165533  ...
# TerrainParks        0.307074  0.156680  0.366571  0.279219  0.250159  ...
# LongestRun_mi       0.442499  0.003807  0.202179  0.175676  0.179178  ...
# SkiableTerrain_ac   0.371155  0.046029  0.198545  0.124832  0.174349  ...
# Snow Making_ac      0.533247  0.261716  0.415989  0.166028  0.052228  ...
# daysOpenLastYear    0.279883  0.109587  0.150444  0.118585  0.018781  ...
# yearsOpen           0.048387  0.062365  0.011446  0.194646  0.074697  ...
# averageSnowfall     0.121476  0.159470  0.039321  0.122717  0.353678  ...
# AdultWeekday        0.486826  0.163097  0.278264  0.268240  0.118024  ...
# AdultWeekend        0.469283  0.211292  0.311259  0.251969  0.069971  ...
# projectedDaysOpen   0.239883  0.064793  0.111370  0.160205  0.026935  ...
# NightSkiing_ac      0.335485  0.220404  0.391432  0.016295  0.175147  ...
# clusters            0.215264  0.041653  0.049831  0.046568  0.296880  ...
#
#                    SkiableTerrain_ac  Snow Making_ac  daysOpenLastYear  \
# summit_elev                 0.564284        0.016761          0.326688
# vertical_drop               0.663569        0.302954          0.304855
# trams                            NaN             NaN               NaN
# fastEight                        NaN             NaN               NaN
# fastSixes                        NaN             NaN               NaN
# fastQuads                   0.371155        0.533247          0.279883
# quad                        0.046029        0.261716          0.109587
# triple                      0.198545        0.415989          0.150444
# double                      0.124832        0.166028          0.118585
# surface                     0.174349        0.052228          0.018781
# total_chairs                0.160329        0.485813          0.229260
# Runs                        0.608689        0.531846          0.351776
# TerrainParks                0.127175        0.383636          0.195030
# LongestRun_mi               0.492375        0.397121          0.243076
# SkiableTerrain_ac           1.000000        0.313280          0.237411
# Snow Making_ac              0.313280        1.000000          0.241755
# daysOpenLastYear            0.237411        0.241755          1.000000
# yearsOpen                   0.167328        0.114490          0.204620
# averageSnowfall             0.596634        0.030476          0.397503
# AdultWeekday                0.378109        0.384879          0.375193
# AdultWeekend                0.239543        0.443864          0.376398
# projectedDaysOpen           0.275574        0.218640          0.731224
# NightSkiing_ac              0.308488        0.585527          0.050074
# clusters                    0.301801        0.039010          0.240967
#
#                    yearsOpen  averageSnowfall  AdultWeekday  AdultWeekend  \
# summit_elev         0.205113         0.693658      0.412575      0.245119
# vertical_drop       0.241737         0.594301      0.642132      0.572197
# trams                    NaN              NaN           NaN           NaN
# fastEight                NaN              NaN           NaN           NaN
# fastSixes                NaN              NaN           NaN           NaN
# fastQuads           0.048387         0.121476      0.486826      0.469283
# quad                0.062365         0.159470      0.163097      0.211292
# triple              0.011446         0.039321      0.278264      0.311259
# double              0.194646         0.122717      0.268240      0.251969
# surface             0.074697         0.353678      0.118024      0.069971
# total_chairs        0.054012         0.110826      0.355331      0.394463
# Runs                0.249489         0.488939      0.640535      0.596956
# TerrainParks        0.060226         0.054596      0.226032      0.271235
# LongestRun_mi       0.113061         0.399511      0.474224      0.471048
# SkiableTerrain_ac   0.167328         0.596634      0.378109      0.239543
# Snow Making_ac      0.114490         0.030476      0.384879      0.443864
# daysOpenLastYear    0.204620         0.397503      0.375193      0.376398
# yearsOpen           1.000000         0.264783      0.151887      0.134989
# averageSnowfall     0.264783         1.000000      0.375058      0.203880
# AdultWeekday        0.151887         0.375058      1.000000      0.839112
# AdultWeekend        0.134989         0.203880      0.839112      1.000000
# projectedDaysOpen   0.209591         0.408624      0.401629      0.340309
# NightSkiing_ac      0.005670         0.044581      0.062448      0.067977
# clusters            0.059882         0.458745      0.452709      0.467901
#
#                    projectedDaysOpen  NightSkiing_ac  clusters
# summit_elev                 0.281628        0.129007  0.553617
# vertical_drop               0.290717        0.000763  0.577899
# trams                            NaN             NaN       NaN
# fastEight                        NaN             NaN       NaN
# fastSixes                        NaN             NaN       NaN
# fastQuads                   0.239883        0.335485  0.215264
# quad                        0.064793        0.220404  0.041653
# triple                      0.111370        0.391432  0.049831
# double                      0.160205        0.016295  0.046568
# surface                     0.026935        0.175147  0.296880
# total_chairs                0.217459        0.404682  0.046072
# Runs                        0.347248        0.106614  0.403109
# TerrainParks                0.177918        0.323414  0.014252
# LongestRun_mi               0.224205        0.056756  0.467795
# SkiableTerrain_ac           0.275574        0.308488  0.301801
# Snow Making_ac              0.218640        0.585527  0.039010
# daysOpenLastYear            0.731224        0.050074  0.240967
# yearsOpen                   0.209591        0.005670  0.059882
# averageSnowfall             0.408624        0.044581  0.458745
# AdultWeekday                0.401629        0.062448  0.452709
# AdultWeekend                0.340309        0.067977  0.467901
# projectedDaysOpen           1.000000        0.023869  0.204540
# NightSkiing_ac              0.023869        1.000000  0.182148
# clusters                    0.204540        0.182148  1.000000
#
# [24 rows x 24 columns]

# %%
#coef_dict = {}
#for coef, feat in zip(
print(list(zip(model.coef_,X_train)))
#coef_dict[feat] = coef
# Out:
# [(3.4403715214794794, array([-0.58371398,  0.        ,  0.        ,  0.        , -0.40789729,
#        -0.77154219, -0.17474739,  0.19403179,  0.5129694 ,  0.        ,
#        -0.70826631, -0.54841359,  0.52205792, -0.16574182,  1.25151064,
#         0.16812489, -1.02560645, -0.41637296, -1.95114316, -0.07283367,
#        -0.11534274, -0.77198267])), (8.881784197001252e-16, array([-0.64273274,  0.        ,  0.        ,  0.        , -0.40789729,
#        -0.77154219, -0.95438959,  0.86926241, -0.18434838, -0.35457375,
#        -0.05390345,  0.15843059, -0.66969529, -0.31838936, -0.17959756,
#         0.57442672,  1.63895538, -0.88288227, -1.67274397,  0.34680405,
#         0.35986572, -0.77198267])), (-1.7763568394002505e-15, array([ 1.11939889,  0.        ,  0.        ,  0.        ,  2.81819946,
#         0.64159825,  0.60489481, -0.48119883,  1.21028718,  1.418295  ,
#         1.96371536,  1.57211895, -0.27244422, -0.03570874,  1.60928769,
#         0.98072855,  0.7975148 , -0.41637296,  1.8350859 ,  1.01822442,
#        -0.74895403,  1.887918  ])), (1.3322676295501878e-15, array([-0.75233901,  0.        ,  0.        ,  0.        , -0.40789729,
#         2.05473868,  1.38453701, -1.15642945,  2.60492275,  1.77286874,
#        -0.38108488,  0.15843059, -0.00761017, -0.40884716,  0.19051663,
#        -0.96952023, -1.44632674, -1.12546711,  0.10901088, -0.91210913,
#         0.83507419, -0.77198267])), (-0.6670755113104604, array([-0.33077642,  0.        ,  0.        ,  0.        , -0.40789729,
#        -0.77154219,  2.9438214 , -1.15642945,  0.5129694 ,  0.7091475 ,
#        -0.27202441, -1.25525777,  0.65447494, -0.38905951,  0.19051663,
#         0.98072855,  0.86763485, -0.49101445, -1.11594558, -0.07283367,
#         0.26482403, -0.77198267])), (0.6789865821881798, array([-1.07272658,  0.        ,  0.        ,  0.        , -0.40789729,
#        -0.77154219, -0.17474739, -1.15642945,  1.90760496,  0.        ,
#        -0.9809175 ,  0.15843059, -1.33178041, -0.57845553, -0.54971174,
#         2.36215477,  0.86763485,  0.05013635, -1.11594558,  2.23517384,
#        -0.11534274, -0.77198267])), (1.1403871815370532, array([-0.33077642,  0.        ,  0.        ,  0.        , -0.40789729,
#        -0.77154219, -0.95438959,  1.54449303, -0.18434838,  0.        ,
#        -0.65373607, -0.54841359,  0.65447494, -0.61803081, -0.7224317 ,
#        -1.25393151, -1.16584655, -0.70560874, -0.00234879, -1.54156573,
#        -0.3371067 , -0.77198267])), (0.5792964460502861, array([ 0.20713744,  0.        ,  0.        ,  0.        , -0.40789729,
#         0.64159825, -0.95438959, -0.48119883, -0.18434838, -0.7091475 ,
#        -0.10843369, -0.54841359,  0.12480685, -0.38905951, -0.37699179,
#        -0.0756562 ,  0.23655442, -0.41637296, -0.00234879, -0.28265254,
#        -0.74895403, -0.77198267])), (-0.27523903323377386, array([-0.75233901,  0.        ,  0.        ,  0.        , -0.40789729,
#         0.64159825, -0.95438959,  1.54449303, -1.57898394, -0.35457375,
#         0.70951988, -0.54841359, -0.00761017,  0.43919471,  2.65794456,
#        -0.03502602, -0.18416587,  0.51664565,  0.5544496 ,  0.26287651,
#        -0.74895403, -0.77198267])), (0.7066121619127462, array([-3.27403922e-01,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#        -4.07897290e-01, -7.71542194e-01, -1.74747389e-01, -4.81198832e-01,
#        -1.84348379e-01, -7.09147498e-01, -6.53736073e-01, -1.25525777e+00,
#        -8.02112316e-01, -1.26166535e-01, -7.96454537e-01,  1.79333221e+00,
#         1.63895538e+00,  2.38268289e+00, -2.34879321e-03,  1.35393460e+00,
#        -7.48954032e-01,  5.57967669e-01])), (0.09042044095575295, array([-0.75233901,  0.        ,  0.        ,  0.        , -0.40789729,
#        -0.77154219, -0.95438959, -1.15642945, -1.57898394, -2.12744249,
#         0.1642175 , -1.25525777,  1.97864518,  1.00455595, -1.04319733,
#         0.98072855, -1.79692699,  0.8898531 , -1.67274397,  1.18607951,
#        -0.74895403,  0.55796767])), (0.6375782121411114, array([ 1.48194272,  0.        ,  0.        ,  0.        , -0.40789729,
#         0.64159825,  0.60489481,  0.19403179, -0.18434838,  0.35457375,
#         2.8907294 , -0.54841359,  2.6407303 ,  1.17416432,  2.34951607,
#         0.04623435,  0.9377549 ,  0.74990031,  1.66804638,  0.76644178,
#        -0.74895403,  0.55796767])), (0.696800725436012, array([ 0.93391135,  0.        ,  0.        ,  0.        , -0.40789729,
#        -0.77154219, -0.95438959,  0.19403179, -0.88166616, -1.06372125,
#         0.32780821, -1.25525777, -0.80211232,  2.53668491, -1.04319733,
#        -1.86338425,  0.7975148 ,  1.44966427, -0.39210767,  3.41015948,
#        -0.74895403,  0.55796767])), (-2.2497954763804042, array([-1.00527657,  0.        ,  0.        ,  0.        , -0.40789729,
#         0.64159825, -0.95438959, -1.15642945, -0.18434838, -1.06372125,
#        -0.76279655, -1.25525777, -0.80211232, -0.57845553, -0.54971174,
#        -1.25393151, -0.67500621, -1.16278786, -1.22730525, -1.75138459,
#        -0.11534274, -0.77198267])), (2.068074100643235, array([ 0.25941121,  0.        ,  0.        ,  0.        , -0.40789729,
#         0.64159825,  1.38453701, -0.48119883, -0.18434838,  0.35457375,
#        -0.21749417, -0.54841359,  0.25722387, -0.29577491,  0.68400222,
#        -1.86338425, -1.72680694, -0.91087283,  0.94420847, -0.91210913,
#         1.46868547, -0.77198267])), (1.486909583924711, array([-1.13174535,  0.        ,  0.        ,  0.        , -0.40789729,
#         2.05473868, -0.17474739, -1.15642945,  1.90760496,  0.7091475 ,
#        -0.87185702, -0.54841359, -0.00761017, -0.59258956, -0.61139744,
#         0.16812489,  0.09631432, -0.83623134, -0.81861523,  0.13698519,
#        -0.19454416, -0.77198267])), (-0.279212323070248, array([-0.9192778 ,  0.        ,  0.        ,  0.        , -0.40789729,
#        -0.77154219,  2.1641792 ,  0.19403179,  0.5129694 ,  1.06372125,
#        -0.70826631,  0.86527477, -1.06694636, -0.46538328, -0.05622616,
#        -0.19754675, -0.11404583, -0.88288227, -0.50346735, -1.75138459,
#         0.51826854, -0.77198267])), (-3.4436054970171504, array([ 1.96252408,  0.        ,  0.        ,  0.        , -0.40789729,
#        -0.77154219, -0.17474739,  0.19403179, -1.57898394, -1.06372125,
#         2.01824559, -0.54841359,  1.97864518,  1.23070045, -0.67308314,
#        -0.23817693, -0.46464607,  0.98315496,  0.83284879,  0.97626065,
#        -0.74895403,  0.55796767])), (9.773515404486348, array([-8.36651533e-01,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#        -4.07897290e-01, -7.71542194e-01, -9.54389587e-01, -4.81198832e-01,
#         1.90760496e+00,  0.00000000e+00,  6.26784346e-04,  1.57211895e+00,
#        -2.72444221e-01, -5.64321497e-01, -5.37374605e-01, -5.63218398e-01,
#        -1.16584655e+00, -9.01542646e-01, -1.22730525e+00,  3.46804054e-01,
#        -1.94544155e-01, -7.71982665e-01])), (0.2117845614870404, array([ 0.25941121,  0.        ,  0.        ,  0.        , -0.40789729,
#         0.64159825, -0.17474739,  0.19403179,  0.5129694 ,  0.35457375,
#         0.32780821,  2.27896313,  1.31656006, -0.31556255,  0.56063082,
#        -0.23817693,  1.42859524, -0.34173147, -0.67050686, -0.91210913,
#         0.12226149, -0.77198267])), (-0.7871717343344758, array([-0.75233901,  0.        ,  0.        ,  0.        , -0.40789729,
#         0.64159825, -0.95438959, -0.48119883, -0.18434838, -0.7091475 ,
#        -1.14450822, -1.25525777, -0.80211232, -0.58693595, -0.58672316,
#        -1.25393151,  0.02619427, -0.88288227, -1.28298509, -1.121928  ,
#        -0.16286359, -0.77198267])), (2.382692013323695, array([-0.41508894,  0.        ,  0.        ,  0.        , -0.40789729,
#         0.64159825, -0.17474739, -1.15642945,  0.5129694 , -0.35457375,
#        -0.87185702,  0.15843059, -0.00761017, -0.35231103, -1.04319733,
#         1.79333221, -0.81524631,  2.38268289,  1.05556815,  1.3539346 ,
#        -0.74895403,  0.55796767]))]

# %%
pd.DataFrame(abs(lm.coef_), X.columns, columns=['Coefficient'])
# Out:
#                     Coefficient
# vertical_drop      3.440372e+00
# trams              8.881784e-16
# fastEight          1.776357e-15
# fastSixes          1.332268e-15
# fastQuads          6.670755e-01
# quad               6.789866e-01
# triple             1.140387e+00
# double             5.792964e-01
# surface            2.752390e-01
# total_chairs       7.066122e-01
# Runs               9.042044e-02
# TerrainParks       6.375782e-01
# LongestRun_mi      6.968007e-01
# SkiableTerrain_ac  2.249795e+00
# Snow Making_ac     2.068074e+00
# daysOpenLastYear   1.486910e+00
# yearsOpen          2.792123e-01
# averageSnowfall    3.443605e+00
# AdultWeekday       9.773515e+00
# projectedDaysOpen  2.117846e-01
# NightSkiing_ac     7.871717e-01
# clusters           2.382692e+00

# %%
print(metrics.mean_absolute_error(Y_test, y_pred))
# Out:
# 5.941492328505132
